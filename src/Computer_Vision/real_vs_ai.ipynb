# %%
import tensorflow as tf

from keras import layers, Sequential, applications

# %%
body = applications.Xception(weights="imgnet")
model_layers = [
    
]

# %%
model = Sequential(layers=model_layers)
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["binary_accuracy"]
)
